# %% [markdown]
# # Drug-Drug Similarity

# %%
import networkx as nx

G = nx.read_gml('../Data/203_Diagnoses/complete_HG.gml')

# %%
class heterogeneous_Graph:
    def __init__(self, G):
        self.HG = G
        Nodes = list(self.HG.nodes())
        self.Patients =    [v for v in Nodes if v[0]=='C']
        self.Visits =      [v for v in Nodes if v[0]=='V']
        self.Medications = [v for v in Nodes if v[0]=='M']
        self.Diagnoses  =  [v for v in Nodes if v[0]=='D']
        self.Procedures =  [v for v in Nodes if v[0]=='P']
        self.Labs       =  [v for v in Nodes if v[0]=='L']
        self.MicroBio   =  [v for v in Nodes if v[0]=='B']
        self.Nodes = self.Patients  + self.Visits + self.Medications + self.Diagnoses + self.Procedures + self.Labs + self.MicroBio
        

M = heterogeneous_Graph(G).Medications

# %%
M
# Out:
# ['M_Pneumococcal Vac Polyvalent',
#  'M_Bisacodyl',
#  'M_Senna',
#  'M_Docusate Sodium (Liquid)',
#  'M_Heparin',
#  'M_Simvastatin',
#  'M_Aspirin',
#  'M_Donepezil',
#  'M_Gabapentin',
#  'M_Namenda',
#  'M_Tolterodine',
#  'M_Metoprolol Succinate XL',
#  'M_Tamsulosin',
#  'M_Docusate Sodium',
#  'M_Sodium Chloride 0.9%  Flush',
#  'M_Guaifenesin',
#  'M_Albuterol Inhaler',
#  'M_Amlodipine',
#  'M_Finasteride',
#  'M_Levothyroxine Sodium',
#  'M_Tiotropium Bromide',
#  'M_Azithromycin',
#  'M_PredniSONE',
#  'M_Sodium Chloride Nasal',
#  'M_Heparin Flush (10 units/ml)',
#  'M_Multivitamins',
#  'M_Ferrous Sulfate',
#  'M_Ipratropium Bromide Neb',
#  'M_Albuterol 0.083% Neb Soln',
#  'M_Sertraline',
#  'M_Allopurinol',
#  'M_Pantoprazole',
#  'M_Furosemide',
#  'M_Carvedilol',
#  'M_Metoprolol Tartrate',
#  'M_Lactulose',
#  'M_Rifaximin',
#  'M_Fentanyl Citrate',
#  'M_Midazolam',
#  'M_Propofol',
#  'M_Atropine Sulfate',
#  'M_Chlorhexidine Gluconate 0.12% Oral Rinse',
#  'M_Ipratropium Bromide MDI',
#  'M_Morphine Sulfate',
#  'M_1/2 NS',
#  'M_Vial',
#  'M_0.9% Sodium Chloride',
#  'M_Iso-Osmotic Dextrose',
#  'M_0.9% Sodium Chloride (Mini Bag Plus)',
#  'M_NS',
#  'M_5% Dextrose',
#  'M_D5W',
#  'M_Pantoprazole Sodium',
#  'M_Vancomycin',
#  'M_CefePIME',
#  'M_MetRONIDAZOLE (FLagyl)',
#  'M_Norepinephrine',
#  'M_Oxycodone-Acetaminophen',
#  'M_Paroxetine',
#  'M_Ascorbic Acid',
#  'M_Creon 10',
#  'M_Acetaminophen',
#  'M_Ondansetron',
#  'M_DiphenhydrAMINE',
#  'M_Ciprofloxacin HCl',
#  'M_Polyethylene Glycol',
#  'M_Magnesium Sulfate',
#  'M_Neutra-Phos',
#  'M_Morphine Sulfate IR',
#  'M_Acetylcysteine 20%',
#  'M_Albumin 25% (12.5g / 50mL)',
#  'M_Valsartan',
#  'M_Calcium Carbonate',
#  'M_Miconazole Powder 2%',
#  'M_Albumin 5% (25g / 500mL)',
#  'M_Sodium Polystyrene Sulfonate',
#  'M_Calcium Gluconate',
#  'M_Albumin 5% (12.5g / 250mL)',
#  'M_D5 1/2NS',
#  'M_LR',
#  'M_D5NS',
#  'M_SW',
#  'M_Potassium Phosphate',
#  'M_Hespan',
#  'M_Influenza Virus Vaccine',
#  'M_Dextrose 50%',
#  'M_Calcitriol',
#  'M_Benzonatate',
#  'M_Spironolactone',
#  'M_Cyanocobalamin',
#  'M_Isosorbide Mononitrate (Extended Release)',
#  'M_HydrALAzine',
#  'M_Levofloxacin',
#  'M_Olanzapine (Disintegrating Tablet)',
#  'M_Cefpodoxime Proxetil',
#  'M_Haloperidol',
#  'M_Olanzapine',
#  'M_OxycoDONE (Immediate Release) ',
#  'M_Glucagon',
#  'M_Omeprazole',
#  'M_Heparin Sodium',
#  'M_Lisinopril',
#  'M_Glipizide',
#  'M_Metoprolol',
#  'M_Sevelamer',
#  'M_Insulin',
#  'M_Magnesium Oxide',
#  'M_Linezolid',
#  'M_Potassium Chloride',
#  'M_Diphenhydramine HCl',
#  'M_Zolpidem Tartrate',
#  'M_Midazolam HCl',
#  'M_Metronidazole',
#  'M_Phytonadione',
#  'M_Alteplase (Catheter Clearance)',
#  'M_Warfarin',
#  'M_Moexipril HCl',
#  'M_Atorvastatin',
#  'M_Metoclopramide',
#  'M_Ceftriaxone',
#  'M_Vancomycin HCl',
#  'M_Ampicillin Sodium',
#  'M_Unasyn',
#  'M_Prochlorperazine',
#  'M_Naproxen',
#  'M_Dronabinol',
#  'M_Tizanidine HCl',
#  'M_traMADOL',
#  'M_Enoxaparin Sodium',
#  'M_Ketorolac',
#  'M_Cosyntropin',
#  'M_Captopril',
#  'M_Cefazolin',
#  'M_Phenylephrine HCl',
#  'M_Heparin Flush CVL  (100 units/ml)',
#  'M_Artificial Tears',
#  'M_Carbidopa-Levodopa (25-250)',
#  'M_Albuterol',
#  'M_Dexamethasone',
#  'M_Fludrocortisone Acetate',
#  'M_Lansoprazole Oral Suspension',
#  'M_Clopidogrel Bisulfate',
#  'M_Hydralazine HCl',
#  'M_Erythromycin 0.5% Ophth Oint',
#  'M_DOBUTamine',
#  'M_Hydrocortisone Na Succ.',
#  'M_Humulin-R Insulin',
#  'M_Multivitamin IV',
#  'M_Enalaprilat',
#  'M_Syringe',
#  'M_Dextrose 5%',
#  'M_Fat Emulsion 20%',
#  'M_Amino Acids 4.25% W/ Dextrose 5%',
#  'M_Iso-Osmotic Sodium Chloride',
#  'M_Azithromycin ',
#  'M_Famotidine',
#  'M_Lansoprazole',
#  'M_Metoprolol XL',
#  'M_Atenolol',
#  'M_Neomycin-Polymyxin-Dexameth Ophth. Oint',
#  'M_Calcium Chloride',
#  'M_Carbidopa-Levodopa (10-100)',
#  'M_Hydrochlorothiazide',
#  'M_Escitalopram Oxalate',
#  'M_Hydrocodone-Acetaminophen',
#  'M_Lorazepam',
#  'M_Prednisone',
#  'M_Metformin',
#  'M_Vitamin D',
#  'M_Fluticasone Propionate 110mcg',
#  'M_Alendronate Sodium',
#  'M_Albuterol Neb Soln',
#  'M_Levetiracetam',
#  'M_Zonisamide',
#  'M_Sodium Chloride',
#  'M_Ampicillin',
#  'M_Tuberculin Protein',
#  'M_Mineral Oil',
#  'M_Cephalexin',
#  'M_Estrogens Conjugated',
#  'M_Nitrofurantoin (Macrodantin)',
#  'M_Hydrocortisone',
#  'M_Neostigmine',
#  'M_Glycopyrrolate',
#  'M_Acetaminophen (Liquid)',
#  'M_HydrALAZINE HCl',
#  'M_Timolol Maleate 0.25%',
#  'M_Brimonidine Tartrate 0.15% Ophth.',
#  'M_Ursodiol',
#  'M_HYDROmorphone (Dilaudid)',
#  'M_Meperidine',
#  'M_Levalbuterol HCl',
#  'M_Hydromorphone',
#  'M_Oxycodone-Acetaminophen Elixir',
#  'M_Doxazosin',
#  'M_Folic Acid',
#  'M_Papain 2.5 % Solution',
#  'M_Potassium Chl 20 mEq / 1000 mL D5 1/2 NS',
#  'M_CefazoLIN',
#  'M_Labetalol',
#  'M_Xopenex',
#  'M_Ondansetron ODT',
#  'M_Loperamide',
#  'M_Potassium Chl 40 mEq / 1000 mL NS',
#  'M_Piperacillin-Tazobactam Na',
#  'M_Ciprofloxacin IV',
#  'M_CeftriaXONE',
#  'M_Ranitidine',
#  'M_Aspirin EC',
#  'M_Milk of Magnesia',
#  'M_Sucralfate',
#  'M_GlipiZIDE',
#  'M_Amiodarone HCl',
#  'M_Exelon',
#  'M_D5W (EXCEL BAG)',
#  'M_Nitroglycerin',
#  'M_Insulin Human Regular',
#  'M_Milrinone',
#  'M_NiCARdipine IV',
#  'M_Diltiazem',
#  'M_Adenosine',
#  'M_Phenytoin Sodium',
#  'M_Carbidopa-Levodopa CR (25-100)',
#  'M_Lacri-Lube Oint',
#  'M_Lansoprazole Oral Solution',
#  'M_NS        (Glass Bottle)',
#  'M_Nafcillin',
#  'M_AcetaZOLamide Sodium',
#  'M_Phenylephrine',
#  'M_Epoetin Alfa',
#  'M_Acetaminophen w/Codeine',
#  'M_Ciprofloxacin',
#  'M_Dorzolamide 2%/Timolol 0.5% Ophth.',
#  'M_Artificial Tear Ointment',
#  'M_Lumigan',
#  'M_Cromolyn',
#  'M_Donepezil 5 mg or Placebo',
#  'M_donepezil 5 mg or placebo',
#  'M_Naphazoline-Pheniramine Ophth. Solution',
#  'M_Zinc Sulfate',
#  'M_TraMADOL (Ultram)',
#  'M_traZODONE HCl',
#  'M_Lidocaine 1%',
#  'M_Heparin Flush PICC (100 units/ml)',
#  'M_Lansoprazole Oral Disintegrating Tab',
#  'M_GlipiZIDE XL',
#  'M_Famotidine (IV)',
#  'M_Nesiritide',
#  'M_Losartan Potassium',
#  'M_Quinidine Gluconate',
#  'M_Digoxin',
#  'M_Isosorbide Dinitrate',
#  'M_Multivitamins W/minerals',
#  'M_Flumazenil',
#  'M_Propofol (Generic)',
#  'M_Albuterol-Ipratropium',
#  'M_Diazepam',
#  'M_Dexamethasone Sod Phosphate',
#  'M_Labetalol HCl',
#  'M_Minoxidil',
#  'M_Clonidine HCl',
#  'M_Phenytoin',
#  'M_Sulfameth/Trimethoprim DS',
#  'M_NS (Glass Bottle)',
#  'M_Soln.',
#  'M_Nitroprusside Sodium',
#  'M_Mannitol 20%',
#  'M_Fondaparinux Sodium',
#  'M_DOPamine',
#  'M_Clopidogrel',
#  'M_PrednisoLONE Acetate 1% Ophth. Susp.',
#  'M_Ciprofloxacin 0.3% Ophth Soln',
#  'M_Acular',
#  'M_Fluticasone-Salmeterol Diskus (250/50) ',
#  'M_traZODONE',
#  'M_NS (Mini Bag Plus)',
#  'M_Piperacillin-Tazobactam',
#  'M_Ziprasidone',
#  'M_Fluocinonide 0.05% Ointment',
#  'M_MethylPREDNISolone Sodium Succ',
#  'M_Thiamine',
#  'M_FoLIC Acid',
#  'M_Cepacol (Menthol)',
#  'M_Potassium Chloride Replacement (Oncology)',
#  'M_Penicillin V Potassium',
#  'M_Nephrocaps',
#  'M_Nystatin Oral Susp.',
#  'M_Chlorhexidine Gluconate',
#  'M_Guaifenesin-Codeine Phosphate',
#  'M_Nitroglycerin Oint. 2%',
#  'M_Nitroglycerin SL',
#  'M_Aluminum-Magnesium Hydrox.-Simethicone',
#  'M_Promethazine',
#  'M_Felodipine',
#  'M_Propra',
#  'M_Propranolol',
#  'M_Lidocaine 5% Patch',
#  'M_Quetiapine Fumarate',
#  'M_Cefepime',
#  'M_Diltiazem Extended-Release',
#  'M_D5LR',
#  'M_Penicillin G Potassium',
#  'M_Ferrous Gluconate',
#  'M_Fluticasone-Salmeterol (100/50)',
#  'M_Venlafaxine XR',
#  'M_Methimazole',
#  'M_Oxycodone (Sustained Release)',
#  'M_Mirtazapine',
#  'M_Amiodarone',
#  'M_Oxybutynin',
#  'M_Phenazopyridine',
#  'M_Torsemide',
#  'M_Dolasetron Mesylate',
#  'M_sodium bicarb',
#  'M_Isotonic Sodium Chloride',
#  'M_Sterile Water For Irrigation',
#  'M_Bag',
#  'M_CeftAZIDime',
#  'M_Fluconazole',
#  'M_Daptomycin',
#  'M_Sodium Bicarbonate',
#  'M_DopAmine',
#  'M_Gentamicin',
#  'M_Vancomycin Enema',
#  'M_Albumin, Human',
#  'M_Vancomycin Oral Liquid',
#  'M_Albumin 5% (25 g)',
#  'M_Albumin 25% (12.5 g)',
#  'M_NIFEdipine CR',
#  'M_Latanoprost 0.005% Ophth. Soln.',
#  'M_Simethicone',
#  'M_Lidocaine Viscous 2%',
#  'M_Benzocaine 20% Spray',
#  'M_DiphenhydrAMINE HCl',
#  'M_Nystatin Oral Suspension',
#  'M_Pioglitazone HCl',
#  'M_Thiamine HCl',
#  'M_Fluticasone-Salmeterol (250/50) ',
#  'M_Oxycodone',
#  'M_Potassium Chl 40 mEq / 1000 mL D5 1/2 NS',
#  'M_Butalbital-Acet-Caffeine',
#  'M_Alprazolam',
#  'M_Acyclovir',
#  'M_Acebutolol HCl',
#  'M_Lidocaine Jelly 2% (Urojet)',
#  'M_Pravastatin',
#  'M_Indomethacin',
#  'M_Nicotine Patch',
#  'M_Sumatriptan Succinate',
#  'M_Cinacalcet',
#  'M_Quinapril',
#  'M_Baclofen',
#  'M_Tacrolimus',
#  'M_Lidocaine 1%/Epinephrine 1:100000',
#  'M_Fentanyl Patch',
#  'M_Meropenem',
#  'M_Tobramycin Sulfate',
#  'M_*NF* Ertapenem Sodium',
#  'M_Nystatin-Triamcinolone Cream',
#  'M_Metolazone',
#  'M_Vecuronium Bromide',
#  'M_AcetaZOLamide',
#  'M_PHENObarbital',
#  'M_Scopolamine Patch',
#  'M_Potassium Chl 20 mEq / 1000 mL NS',
#  'M_Soln',
#  'M_Potassium Chl 20 mEq / 1000 mL D5NS',
#  'M_Fosphenytoin',
#  'M_LeVETiracetam',
#  'M_PENTObarbital Sodium',
#  'M_Sarna Lotion',
#  'M_Lidocaine',
#  'M_Golytely',
#  'M_Vasopressin',
#  'M_Multivitamin 12',
#  'M_Ceftazidime',
#  'M_Pletal',
#  'M_Salmeterol Xinafoate Diskus (50 mcg)',
#  'M_Dobutamine',
#  'M_Calcium Replacement (Oncology)',
#  'M_Danazol',
#  'M_Hydroxyurea',
#  'M_Loperamide HCl',
#  'M_Bismuth Subsalicylate',
#  'M_Tocopheryl',
#  'M_Clarithromycin',
#  'M_Ethambutol HCl',
#  'M_Rifampin',
#  'M_Isoniazid',
#  'M_Pyridoxine HCl',
#  'M_Pyrazinamide',
#  'M_Methylprednisolone Na Succ',
#  'M_Cisatracurium Besylate',
#  'M_Tarceva',
#  'M_sodium bic',
#  'M_Dextromethorphan-Guaifenesin (Sugar Free)',
#  'M_Codeine Sulfate',
#  'M_Amoxicillin-Clavulanic Acid',
#  'M_Glyburide',
#  'M_Nystatin Ointment',
#  'M_Cimetidine',
#  'M_Paclitaxel',
#  'M_Carboplatin',
#  'M_Docetaxel',
#  'M_Sterile Water',
#  'M_Syringe (IV Room)',
#  'M_D5W (Glass Bottle)',
#  'M_Sterile Diluent for Flolan',
#  'M_Valganciclovir HCl',
#  'M_Sulfameth/Trimethoprim',
#  'M_Lamivudine',
#  'M_Sulfameth/Trimethoprim SS',
#  'M_Hepatitis B Immune Globulin (Nabi-HB)',
#  'M_Albumin 5% (12.5 g)',
#  'M_Mycophenolate Mofetil',
#  'M_Albumin 5%',
#  'M_Albumin',
#  'M_Calcium Acetate',
#  'M_Basiliximab',
#  'M_Methylprednisolone Na Succ.',
#  'M_Ganciclovir',
#  'M_Epoprostenol Na',
#  'M_Normocarb',
#  'M_Sodium Chloride ',
#  'M_Nitroglycerin Ointment  2%',
#  'M_Cetylpyridinium Chl (Cepacol)',
#  'M_Clonazepam',
#  'M_Tirofiban',
#  'M_Albumin 25% (12.5gm)',
#  'M_Octreotide Acetate',
#  'M_Propoxyphene Nap.-Apap (N-100)',
#  'M_Sirolimus',
#  'M_Lactulose Enema',
#  'M_Sodium Phosphate',
#  'M_Morphine SR (MS Contin)',
#  'M_Erythromycin',
#  'M_Candesartan',
#  'M_Gentamicin Sulfate',
#  'M_Esmolol',
#  'M_Dostinex',
#  'M_Midodrine HCl',
#  'M_CefTRIAXone',
#  'M_Cabergoline',
#  'M_Ranitidine (Liquid)',
#  'M_Timolol Maleate 0.5%',
#  'M_Maalox/Diphenhydramine/Lidocaine',
#  'M_Heparin Flush CRRT (5000 Units/mL)',
#  'M_Prismasate (B32 K2)',
#  'M_Sodium Chloride 3% (Hypertonic)',
#  'M_Epinephrine',
#  'M_Solution',
#  'M_Ampicillin-Sulbactam',
#  'M_Methadone HCl',
#  'M_Ibuprofen Suspension',
#  'M_Sulfameth/Trimethoprim Suspension',
#  'M_Clindamycin Suspension',
#  'M_Pseudoephedrine HCl',
#  'M_Citalopram Hydrobromide',
#  'M_Dicloxacillin',
#  'M_Promethazine HCl',
#  'M_Amphotericin B',
#  'M_Nadolol',
#  'M_Heparin Flush ',
#  'M_Heparin CRRT',
#  'M_AMP',
#  'M_Montelukast Sodium',
#  'M_Heparin Flush Hickman (100 units/ml)',
#  'M_Paroxetine HCl',
#  'M_Fleet Phospho-Soda',
#  'M_tucks',
#  'M_Lidocaine Jelly 2%',
#  'M_HYDROmorphone-HP',
#  'M_Epinephrine HCl',
#  'M_PNEUMOcoccal Vac Polyvalent',
#  'M_Demeclocycline',
#  'M_OxycoDONE-Acetaminophen Elixir',
#  'M_OxycoDONE Liquid',
#  'M_Clindamycin',
#  'M_Clonidine Patch 0.1 mg/24 hr',
#  'M_Methylprednisolone',
#  'M_Heparin Flush (100 units/ml)',
#  'M_Viokase-8',
#  'M_Morphine Sulfate (Concentrated Oral Soln)',
#  'M_Hyoscyamine',
#  'M_MetFORMIN XR (Glucophage XR)',
#  'M_Artificial Tears Preserv. Free',
#  'M_Cyproheptadine',
#  'M_Ascorbic Acid (Liquid)',
#  'M_Morphine Sulfate (Oral Soln.)',
#  'M_Duloxetine',
#  'M_Potassium Chloride (Powder)',
#  'M_Creon 12',
#  'M_Acetaminophen IV',
#  'M_Capsaicin 0.025%',
#  'M_Fleet Enema',
#  'M_Sodium Bicarbo',
#  'M_Pancrelipase 5000',
#  'M_Phosphorus',
#  'M_Lactated Ringers',
#  'M_NORepinephrine',
#  'M_Ferrous Sulfate (Liquid)',
#  'M_0.45% Sodium Chloride',
#  'M_PHENYLEPHrine',
#  'M_NS (Irrigation Bottle)',
#  'M_Nystatin',
#  'M_Potassium Chl 20 mEq / 1000 mL D5W',
#  'M_Citalopram',
#  'M_Naloxone',
#  'M_Multiple Vitamins Liq.',
#  'M_Guaifenesin-Dextromethorphan',
#  'M_Albuterol MDI',
#  'M_Nystatin-Triamcinolone Ointment',
#  'M_Enalapril Maleate',
#  'M_Clonidine Patch 0.3 mg/24 hr',
#  'M_Esmolol in Saline (Iso-osm)',
#  'M_Potassium Chl 40 mEq / 1000 mL D5W',
#  'M_CeftazIDIME',
#  'M_Phenazopyridine HCl',
#  'M_Methylene Blue 1%',
#  'M_Desitin',
#  'M_Lidocaine 2%',
#  'M_LeVETiracetam Solution',
#  'M_Succinylcholine',
#  'M_Etomidate',
#  'M_Epidural Bag',
#  'M_HYDROmorphone P.F.',
#  'M_Bupivacaine 0.1%',
#  'M_Heparin Lock Flush',
#  'M_Sodium CITRATE 4%',
#  'M_Heparin Flush (5000 Units/mL)',
#  'M_Midodrine',
#  'M_Nystatin Cream',
#  'M_Risperidone',
#  'M_sevelamer HYDROCHLORIDE',
#  'M_Prismasate (B22 K4)',
#  'M_Citrate Dextrose 3% (ACD-A) CRRT',
#  'M_Cilostazol',
#  'M_Fosinopril',
#  'M_CloniDINE',
#  'M_Rosuvastatin Calcium',
#  'M_Meclizine',
#  'M_Imipramine',
#  'M_Verapamil SR',
#  'M_Divalproex (EXTended Release)',
#  'M_Divalproex Sod. Sprinkles',
#  'M_Vigamox',
#  'M_Pentamidine-Inhalation',
#  'M_Methadone',
#  'M_Collagenase Ointment',
#  'M_Dapsone',
#  'M_Atovaquone Suspension',
#  'M_Methylnaltrexone',
#  'M_ChlorproMAZINE',
#  'M_Syringe (0.9% Sodium Chloride)',
#  'M_Doxycycline Hyclate',
#  'M_Xopenex Neb',
#  'M_Clotrimazole',
#  'M_Magnesium Citrate',
#  'M_Gelclair',
#  'M_Pregabalin',
#  'M_Syringe (Chemo)',
#  'M_Rituximab',
#  'M_Etoposide',
#  'M_Cyclophosphamide',
#  'M_DOXOrubicin',
#  'M_VinCRIStine (Oncovin)',
#  'M_Leucovorin Calcium',
#  'M_Filgrastim',
#  'M_Methotrexate Sodium',
#  'M_Cytarabine',
#  'M_Hydrocortisone Na Succinate',
#  'M_Gammagard Liquid',
#  'M_*NF* Rasburicase',
#  'M_Mesna',
#  'M_Methotrexate Sodium P.F.',
#  'M_Fluticasone Propionate NASAL',
#  'M_Aluminum Hydroxide Suspension',
#  'M_Bacitracin/Polymyxin B Sulfate Opht. Oint',
#  'M_Nortriptyline',
#  'M_Tizanidine',
#  'M_sodium bicar',
#  'M_Caphosol',
#  'M_Bupivacaine 0.75%',
#  'M_Bacitracin Ointment',
#  'M_Megestrol Acetate',
#  'M_Fluticasone-Salmeterol Diskus (100/50)',
#  'M_Thioridazine HCl',
#  'M_Carbamazepine XR',
#  'M_Clotrimazole Cream',
#  'M_Ny',
#  'M_Theophylline (Oral Solution)',
#  'M_0.83% Sodium Chloride']
