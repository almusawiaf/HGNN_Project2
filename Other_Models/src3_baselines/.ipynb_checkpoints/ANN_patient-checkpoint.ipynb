# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import precision_score, f1_score, roc_auc_score, accuracy_score
import matplotlib.pyplot as plt

# %%
X = np.load('../../Data/tabular/patient_level/X.npy')
Y = np.load('../../Data/tabular/visit_level/Y.npy')

X.shape, Y.shape
# Out:
# ((56465, 661), (56465, 203))

# %% [markdown]
# ## Selecting the top 10 frequent labels

# %%
num_Labels = 25

label_frequencies = np.sum(Y, axis=0)

top_10_labels_indices = np.argsort(label_frequencies)[-num_Labels:]  # Get indices of top 10 labels

Y_top10 = Y[:, top_10_labels_indices]

print(f"Original Y shape: {Y.shape}")
print(f"New Y shape with top 10 labels: {Y_top10.shape}")

Y = Y_top10
# Out:
# Original Y shape: (56465, 203)
# New Y shape with top 10 labels: (56465, 25)

# %% [markdown]
# ## Removing observation with no labels

# %%
# Step 1: Identify rows where no labels are present (all zeros)
rows_with_labels = np.sum(Y, axis=1) > 0

# Step 2: Filter out these rows from both X and Y
X_filtered = X[rows_with_labels]
Y_filtered = Y[rows_with_labels]

print(f"Original X shape: {X.shape}")
print(f"Original Y shape: {Y.shape}")
print(f"Filtered X shape: {X_filtered.shape}")
print(f"Filtered Y shape: {Y_filtered.shape}")

X, Y = X_filtered, Y_filtered
# Out:
# Original X shape: (56465, 661)
# Original Y shape: (56465, 25)
# Filtered X shape: (53167, 661)
# Filtered Y shape: (53167, 25)

# %%
def plot_metrics(loss_history, metrics_history):
    epochs = len(loss_history)
    fig, ax1 = plt.subplots()

    # Plot loss on left y-axis with a distinct color (red)
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss', color='tab:red')
    ax1.plot(range(epochs), loss_history, color='tab:red', label='Loss', linewidth=2)
    ax1.tick_params(axis='y', labelcolor='tab:red')

    # Create a second y-axis for metrics
    ax2 = ax1.twinx()
    ax2.set_ylabel('Metrics', color='tab:blue')
    
    # Define distinct colors for each metric
    metric_colors = ['tab:blue', 'tab:green', 'tab:orange', 'tab:purple', 'tab:brown', 'tab:pink']
    
    # Plot each metric with its own color
    for i, (metric, values) in enumerate(metrics_history.items()):
        ax2.plot(range(epochs), values, label=metric, color=metric_colors[i % len(metric_colors)], linewidth=2)

    ax2.tick_params(axis='y', labelcolor='tab:blue')

    # Show legends for both loss and metrics
    fig.tight_layout()
    ax2.legend(loc='upper left')
    ax1.legend(loc='upper right')
    plt.title('Loss and Metrics Over Epochs')
    plt.show()
    
    

def compute_metrics(y_true, y_pred, y_prob):
    from sklearn.metrics import precision_score, f1_score, roc_auc_score, accuracy_score
    metrics = {}
    
    # Micro precision
    metrics['micro_precision'] = precision_score(y_true, y_pred, average='micro', zero_division=0)
    
    # Macro precision
    metrics['macro_precision'] = precision_score(y_true, y_pred, average='macro', zero_division=0)
    
    # F1 Score
    metrics['f1_score'] = f1_score(y_true, y_pred, average='macro', zero_division=0)
    
    # Precision at k=4
    top_k = torch.topk(y_prob, k=4, dim=1).indices
    y_pred_at_k = torch.zeros_like(y_pred)
    for i, row in enumerate(top_k):
        y_pred_at_k[i, row] = 1
    metrics['precision_at_k'] = precision_score(y_true, y_pred_at_k, average='micro', zero_division=0)
    
    # AUC
    metrics['auc'] = roc_auc_score(y_true, y_prob, average='macro')
    
    # Accuracy
    metrics['accuracy'] = accuracy_score(y_true, y_pred)
    
    return metrics



# # Define the model
# class MultilabelANN(nn.Module):
#     def __init__(self, input_dim, output_dim):
#         super(MultilabelANN, self).__init__()
#         self.fc1 = nn.Linear(input_dim, 512)  # First hidden layer
#         self.fc2 = nn.Linear(512, 256)        # Second hidden layer
#         self.fc3 = nn.Linear(256, output_dim) # Output layer
#         self.relu = nn.ReLU()
#         self.sigmoid = nn.Sigmoid()

#     def forward(self, x):
#         x = self.relu(self.fc1(x))  # Apply ReLU on the first hidden layer
#         x = self.relu(self.fc2(x))  # Apply ReLU on the second hidden layer
#         x = self.sigmoid(self.fc3(x))  # Apply Sigmoid on the output layer
#         return x
    

# 2. Adjust the model by adding extra layers and dropout
class MultilabelANN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(MultilabelANN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 128)
        self.dropout = nn.Dropout(0.3)  # Dropout layer
        self.fc4 = nn.Linear(128, output_dim)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        x = self.sigmoid(self.fc4(x))
        return x
    

# Function to plot label frequencies
def plot_label_frequencies(Y):
    # Sum the occurrences of each label across all samples (column-wise sum)
    label_frequencies = np.sum(Y, axis=0)
    
    # Plotting
    plt.figure(figsize=(12, 6))
    plt.bar(range(len(label_frequencies)), label_frequencies, color='skyblue')
    plt.title('Label Frequency Distribution')
    plt.xlabel('Labels')
    plt.ylabel('Frequency')
    plt.show()

# Assuming Y is your label matrix
# Call the function to plot label frequencies
plot_label_frequencies(Y)

# %%
from sklearn.model_selection import train_test_split
import torch
import torch.optim as optim
import torch.nn as nn

# Step 0: Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Step 1: Split the data into train and test sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Step 2: Convert data to PyTorch tensors and move to GPU if available
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
Y_train_tensor = torch.tensor(Y_train, dtype=torch.float32).to(device)
Y_test_tensor = torch.tensor(Y_test, dtype=torch.float32).to(device)

# Step 3: Model initialization and move to GPU
input_dim = X_train.shape[1]  # 661 features
output_dim = Y_train.shape[1]  # 203 labels
model = MultilabelANN(input_dim, output_dim).to(device)

# Step 4: Define loss and optimizer
criterion = nn.BCELoss()  # Binary Cross-Entropy Loss for multilabel classification

optimizer = optim.Adam(model.parameters(), lr=0.005)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# Step 5: Training loop parameters
num_epochs = 50
batch_size = 64

# Step 6: Create DataLoader for batching the training data
train_data = torch.utils.data.TensorDataset(X_train_tensor, Y_train_tensor)
train_loader = torch.utils.data.DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)

# Step 7: Training loop with metric calculation and plotting
loss_history = []
metrics_history = {
    'micro_precision': [],
    'macro_precision': [],
    'f1_score': [],
    'precision_at_k': [],
    'auc': [],
    'accuracy': []
}

for epoch in range(num_epochs):
    model.train()  # Set model to training mode
    running_loss = 0.0
    for i, (inputs, labels) in enumerate(train_loader):
        # Zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        inputs, labels = inputs.to(device), labels.to(device)  # Move data to GPU
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        # Accumulate loss for this batch
        running_loss += loss.item()
    
    avg_loss = running_loss / len(train_loader)
    loss_history.append(avg_loss)
    
    # Evaluation and metrics computation
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        X_test_tensor = X_test_tensor.to(device)
        Y_test_tensor = Y_test_tensor.to(device)
        outputs = model(X_test_tensor)
        
        # Convert outputs to binary predictions (multilabel)
        predicted = (outputs > 0.5).float()

        # Compute metrics
        metrics = compute_metrics(Y_test, predicted, outputs)
        
        # Store metrics for plotting
        for key in metrics_history:
            metrics_history[key].append(metrics[key])
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, "
          f"Micro Precision: {metrics['micro_precision']:.4f}, "
          f"Macro Precision: {metrics['macro_precision']:.4f}, "
          f"F1 Score: {metrics['f1_score']:.4f}, "
          f"Precision at k=4: {metrics['precision_at_k']:.4f}, "
          f"AUC: {metrics['auc']:.4f}, "
          f"Accuracy: {metrics['accuracy']:.4f}")

# Step 8: Plot the loss and metrics
plot_metrics(loss_history, metrics_history)
# Out:
# Using device: cpu
# Epoch [1/50], Loss: 0.3828, Micro Precision: 0.6416, Macro Precision: 0.4675, F1 Score: 0.2814, Precision at k=4: 0.4727, AUC: 0.7547, Accuracy: 0.0856
# Epoch [2/50], Loss: 0.3664, Micro Precision: 0.6722, Macro Precision: 0.5124, F1 Score: 0.2946, Precision at k=4: 0.4809, AUC: 0.7623, Accuracy: 0.0854
# Epoch [3/50], Loss: 0.3641, Micro Precision: 0.6883, Macro Precision: 0.5204, F1 Score: 0.2887, Precision at k=4: 0.4815, AUC: 0.7609, Accuracy: 0.0772
# Epoch [4/50], Loss: 0.3627, Micro Precision: 0.6696, Macro Precision: 0.5380, F1 Score: 0.2958, Precision at k=4: 0.4808, AUC: 0.7625, Accuracy: 0.0839
# Epoch [5/50], Loss: 0.3617, Micro Precision: 0.6703, Macro Precision: 0.5416, F1 Score: 0.3088, Precision at k=4: 0.4827, AUC: 0.7630, Accuracy: 0.0848
# Epoch [6/50], Loss: 0.3610, Micro Precision: 0.6673, Macro Precision: 0.5877, F1 Score: 0.2975, Precision at k=4: 0.4807, AUC: 0.7641, Accuracy: 0.0833
# Epoch [7/50], Loss: 0.3601, Micro Precision: 0.6690, Macro Precision: 0.6159, F1 Score: 0.3097, Precision at k=4: 0.4845, AUC: 0.7644, Accuracy: 0.0807
# Epoch [8/50], Loss: 0.3597, Micro Precision: 0.6734, Macro Precision: 0.5790, F1 Score: 0.2883, Precision at k=4: 0.4819, AUC: 0.7638, Accuracy: 0.0819
# Epoch [9/50], Loss: 0.3588, Micro Precision: 0.6770, Macro Precision: 0.5727, F1 Score: 0.3032, Precision at k=4: 0.4788, AUC: 0.7655, Accuracy: 0.0802
# Epoch [10/50], Loss: 0.3587, Micro Precision: 0.6872, Macro Precision: 0.6290, F1 Score: 0.2963, Precision at k=4: 0.4821, AUC: 0.7646, Accuracy: 0.0832
# Epoch [11/50], Loss: 0.3580, Micro Precision: 0.6604, Macro Precision: 0.6191, F1 Score: 0.3019, Precision at k=4: 0.4803, AUC: 0.7638, Accuracy: 0.0846
# Epoch [12/50], Loss: 0.3574, Micro Precision: 0.6632, Macro Precision: 0.5874, F1 Score: 0.3154, Precision at k=4: 0.4811, AUC: 0.7641, Accuracy: 0.0859
# Epoch [13/50], Loss: 0.3568, Micro Precision: 0.6658, Macro Precision: 0.5743, F1 Score: 0.3108, Precision at k=4: 0.4769, AUC: 0.7619, Accuracy: 0.0815
# Epoch [14/50], Loss: 0.3565, Micro Precision: 0.6477, Macro Precision: 0.5652, F1 Score: 0.3214, Precision at k=4: 0.4805, AUC: 0.7618, Accuracy: 0.0857
# Epoch [15/50], Loss: 0.3562, Micro Precision: 0.6576, Macro Precision: 0.5825, F1 Score: 0.3213, Precision at k=4: 0.4803, AUC: 0.7644, Accuracy: 0.0833
# Epoch [16/50], Loss: 0.3559, Micro Precision: 0.6565, Macro Precision: 0.5655, F1 Score: 0.3044, Precision at k=4: 0.4806, AUC: 0.7636, Accuracy: 0.0833
# Epoch [17/50], Loss: 0.3555, Micro Precision: 0.6639, Macro Precision: 0.5778, F1 Score: 0.3143, Precision at k=4: 0.4806, AUC: 0.7630, Accuracy: 0.0812
# Epoch [18/50], Loss: 0.3550, Micro Precision: 0.6548, Macro Precision: 0.5878, F1 Score: 0.3215, Precision at k=4: 0.4814, AUC: 0.7637, Accuracy: 0.0812
# Epoch [19/50], Loss: 0.3549, Micro Precision: 0.6654, Macro Precision: 0.5873, F1 Score: 0.3107, Precision at k=4: 0.4828, AUC: 0.7640, Accuracy: 0.0823
# Epoch [20/50], Loss: 0.3542, Micro Precision: 0.6640, Macro Precision: 0.5908, F1 Score: 0.3089, Precision at k=4: 0.4794, AUC: 0.7622, Accuracy: 0.0838
# Epoch [21/50], Loss: 0.3540, Micro Precision: 0.6667, Macro Precision: 0.5963, F1 Score: 0.3038, Precision at k=4: 0.4818, AUC: 0.7624, Accuracy: 0.0806
# Epoch [22/50], Loss: 0.3532, Micro Precision: 0.6656, Macro Precision: 0.5937, F1 Score: 0.3093, Precision at k=4: 0.4802, AUC: 0.7621, Accuracy: 0.0828
# Epoch [23/50], Loss: 0.3534, Micro Precision: 0.6508, Macro Precision: 0.5886, F1 Score: 0.3166, Precision at k=4: 0.4785, AUC: 0.7611, Accuracy: 0.0815
# Epoch [24/50], Loss: 0.3529, Micro Precision: 0.6640, Macro Precision: 0.5864, F1 Score: 0.3121, Precision at k=4: 0.4795, AUC: 0.7604, Accuracy: 0.0843
# Epoch [25/50], Loss: 0.3526, Micro Precision: 0.6655, Macro Precision: 0.5826, F1 Score: 0.3056, Precision at k=4: 0.4786, AUC: 0.7607, Accuracy: 0.0831
# Epoch [26/50], Loss: 0.3521, Micro Precision: 0.6579, Macro Precision: 0.5941, F1 Score: 0.3111, Precision at k=4: 0.4790, AUC: 0.7616, Accuracy: 0.0849
# Epoch [27/50], Loss: 0.3522, Micro Precision: 0.6541, Macro Precision: 0.5801, F1 Score: 0.3191, Precision at k=4: 0.4797, AUC: 0.7624, Accuracy: 0.0836
# Epoch [28/50], Loss: 0.3519, Micro Precision: 0.6655, Macro Precision: 0.5814, F1 Score: 0.3091, Precision at k=4: 0.4805, AUC: 0.7612, Accuracy: 0.0842
# Epoch [29/50], Loss: 0.3512, Micro Precision: 0.6620, Macro Precision: 0.5869, F1 Score: 0.3156, Precision at k=4: 0.4773, AUC: 0.7606, Accuracy: 0.0815
# Epoch [30/50], Loss: 0.3512, Micro Precision: 0.6620, Macro Precision: 0.5874, F1 Score: 0.3063, Precision at k=4: 0.4772, AUC: 0.7606, Accuracy: 0.0852
# Epoch [31/50], Loss: 0.3512, Micro Precision: 0.6554, Macro Precision: 0.5714, F1 Score: 0.3147, Precision at k=4: 0.4775, AUC: 0.7602, Accuracy: 0.0842
# Epoch [32/50], Loss: 0.3509, Micro Precision: 0.6498, Macro Precision: 0.5794, F1 Score: 0.3245, Precision at k=4: 0.4784, AUC: 0.7602, Accuracy: 0.0842
# Epoch [33/50], Loss: 0.3506, Micro Precision: 0.6481, Macro Precision: 0.5796, F1 Score: 0.3254, Precision at k=4: 0.4781, AUC: 0.7597, Accuracy: 0.0816
# Epoch [34/50], Loss: 0.3502, Micro Precision: 0.6400, Macro Precision: 0.5631, F1 Score: 0.3243, Precision at k=4: 0.4780, AUC: 0.7595, Accuracy: 0.0840
# Epoch [35/50], Loss: 0.3504, Micro Precision: 0.6514, Macro Precision: 0.5780, F1 Score: 0.3112, Precision at k=4: 0.4779, AUC: 0.7589, Accuracy: 0.0840
# Epoch [36/50], Loss: 0.3502, Micro Precision: 0.6471, Macro Precision: 0.5726, F1 Score: 0.3185, Precision at k=4: 0.4790, AUC: 0.7595, Accuracy: 0.0826
# Epoch [37/50], Loss: 0.3497, Micro Precision: 0.6592, Macro Precision: 0.5713, F1 Score: 0.3096, Precision at k=4: 0.4777, AUC: 0.7584, Accuracy: 0.0841
# Epoch [38/50], Loss: 0.3493, Micro Precision: 0.6499, Macro Precision: 0.5832, F1 Score: 0.3122, Precision at k=4: 0.4771, AUC: 0.7594, Accuracy: 0.0826
# Epoch [39/50], Loss: 0.3497, Micro Precision: 0.6508, Macro Precision: 0.5730, F1 Score: 0.3118, Precision at k=4: 0.4785, AUC: 0.7607, Accuracy: 0.0840
# Epoch [40/50], Loss: 0.3490, Micro Precision: 0.6483, Macro Precision: 0.5760, F1 Score: 0.3143, Precision at k=4: 0.4763, AUC: 0.7596, Accuracy: 0.0840
# Epoch [41/50], Loss: 0.3486, Micro Precision: 0.6652, Macro Precision: 0.5896, F1 Score: 0.3076, Precision at k=4: 0.4785, AUC: 0.7589, Accuracy: 0.0837
# Epoch [42/50], Loss: 0.3487, Micro Precision: 0.6393, Macro Precision: 0.5645, F1 Score: 0.3224, Precision at k=4: 0.4790, AUC: 0.7590, Accuracy: 0.0833
# Epoch [43/50], Loss: 0.3484, Micro Precision: 0.6420, Macro Precision: 0.5668, F1 Score: 0.3208, Precision at k=4: 0.4781, AUC: 0.7577, Accuracy: 0.0817
# Epoch [44/50], Loss: 0.3480, Micro Precision: 0.6368, Macro Precision: 0.5710, F1 Score: 0.3183, Precision at k=4: 0.4795, AUC: 0.7575, Accuracy: 0.0842
# Epoch [45/50], Loss: 0.3479, Micro Precision: 0.6418, Macro Precision: 0.5590, F1 Score: 0.3168, Precision at k=4: 0.4770, AUC: 0.7568, Accuracy: 0.0847
# Epoch [46/50], Loss: 0.3477, Micro Precision: 0.6488, Macro Precision: 0.5683, F1 Score: 0.3217, Precision at k=4: 0.4758, AUC: 0.7579, Accuracy: 0.0799
# Epoch [47/50], Loss: 0.3480, Micro Precision: 0.6585, Macro Precision: 0.5848, F1 Score: 0.3116, Precision at k=4: 0.4770, AUC: 0.7565, Accuracy: 0.0820
# Epoch [48/50], Loss: 0.3479, Micro Precision: 0.6603, Macro Precision: 0.5740, F1 Score: 0.3144, Precision at k=4: 0.4762, AUC: 0.7565, Accuracy: 0.0847
# Epoch [49/50], Loss: 0.3472, Micro Precision: 0.6649, Macro Precision: 0.5669, F1 Score: 0.3039, Precision at k=4: 0.4739, AUC: 0.7558, Accuracy: 0.0863
# Epoch [50/50], Loss: 0.3473, Micro Precision: 0.6289, Macro Precision: 0.5669, F1 Score: 0.3258, Precision at k=4: 0.4773, AUC: 0.7573, Accuracy: 0.0860

# %%
# from sklearn.model_selection import train_test_split
# import torch
# import torch.optim as optim
# import torch.nn as nn

# # Step 1: Split the data into train and test sets
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# # Step 2: Convert data to PyTorch tensors
# X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
# X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
# Y_train_tensor = torch.tensor(Y_train, dtype=torch.float32)
# Y_test_tensor = torch.tensor(Y_test, dtype=torch.float32)

# # Step 3: Model initialization
# input_dim = X_train.shape[1]  # 661 features
# output_dim = Y_train.shape[1]  # 203 labels
# model = MultilabelANN(input_dim, output_dim)

# # Step 4: Define loss and optimizer
# criterion = nn.BCELoss()  # Binary Cross-Entropy Loss for multilabel classification

# optimizer = optim.Adam(model.parameters(), lr=0.005)
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# # Step 5: Training loop parameters
# num_epochs = 20
# batch_size = 64

# # Step 6: Create DataLoader for batching the training data
# train_data = torch.utils.data.TensorDataset(X_train_tensor, Y_train_tensor)
# train_loader = torch.utils.data.DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)

# # Step 7: Training loop with metric calculation and plotting
# loss_history = []
# metrics_history = {
#     'micro_precision': [],
#     'macro_precision': [],
#     'f1_score': [],
#     'precision_at_k': [],
#     'auc': [],
#     'accuracy': []
# }

# for epoch in range(num_epochs):
#     model.train()  # Set model to training mode
#     running_loss = 0.0
#     for i, (inputs, labels) in enumerate(train_loader):
#         # Zero the parameter gradients
#         optimizer.zero_grad()
        
#         # Forward pass
#         outputs = model(inputs)
#         loss = criterion(outputs, labels)
        
#         # Backward pass and optimization
#         loss.backward()
#         optimizer.step()
        
#         # Accumulate loss for this batch
#         running_loss += loss.item()
    
#     avg_loss = running_loss / len(train_loader)
#     loss_history.append(avg_loss)
    
#     # Evaluation and metrics computation
#     model.eval()  # Set model to evaluation mode
#     with torch.no_grad():
#         outputs = model(X_test_tensor)
        
#         # Convert outputs to binary predictions (multilabel)
#         predicted = (outputs > 0.5).float()
        
#         # Compute metrics
#         metrics = compute_metrics(Y_test, predicted, outputs)
        
#         # Store metrics for plotting
#         for key in metrics_history:
#             metrics_history[key].append(metrics[key])
    
#     print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, "
#           f"Micro Precision: {metrics['micro_precision']:.4f}, "
#           f"Macro Precision: {metrics['macro_precision']:.4f}, "
#           f"F1 Score: {metrics['f1_score']:.4f}, "
#           f"Precision at k=4: {metrics['precision_at_k']:.4f}, "
#           f"AUC: {metrics['auc']:.4f}, "
#           f"Accuracy: {metrics['accuracy']:.4f}")

# # Step 8: Plot the loss and metrics
# plot_metrics(loss_history, metrics_history)

# %%
# from imblearn.over_sampling import RandomOverSampler
# from sklearn.model_selection import train_test_split
# import numpy as np
# import torch

# # Function to apply RandomOverSampler to the entire dataset, resampling all labels simultaneously
# def apply_random_oversampling(X, Y):
#     ros = RandomOverSampler(sampling_strategy='auto', random_state=42)
    
#     # Flatten the Y matrix into a 1D array of tuples to retain the multilabel structure during resampling
#     Y_flattened = [''.join(map(str, y)) for y in Y]  # Convert each row into a string (e.g., '001')
    
#     # Resample the dataset based on the flattened labels
#     X_resampled, Y_resampled_flattened = ros.fit_resample(X, Y_flattened)
    
#     # Convert the flattened labels back to their original multilabel format
#     Y_resampled = np.array([list(map(int, y)) for y in Y_resampled_flattened])
    
#     return X_resampled, Y_resampled

# # Step 1: Split the data into train and test sets
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# # Step 2: Apply RandomOverSampler to the entire training dataset
# X_train_resampled, Y_train_resampled = apply_random_oversampling(X_train, Y_train)

# # Step 3: Convert the resampled data to PyTorch tensors
# X_train_tensor = torch.tensor(X_train_resampled, dtype=torch.float32)
# X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
# Y_train_tensor = torch.tensor(Y_train_resampled, dtype=torch.float32)
# Y_test_tensor = torch.tensor(Y_test, dtype=torch.float32)

# # Continue with model training as before
# input_dim = X_train.shape[1]  # 661 features
# output_dim = Y_train.shape[1]  # 203 labels
# model = MultilabelANN(input_dim, output_dim)

# # Define loss and optimizer
# criterion = nn.BCELoss()  # Binary Cross-Entropy Loss for multilabel classification
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# # Training loop parameters
# num_epochs = 20
# batch_size = 64

# # Create DataLoader for batching the resampled training data
# train_data = torch.utils.data.TensorDataset(X_train_tensor, Y_train_tensor)
# train_loader = torch.utils.data.DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)

# # Training loop (rest of the code remains the same)
# loss_history = []
# metrics_history = {
#     'micro_precision': [],
#     'macro_precision': [],
#     'f1_score': [],
#     'precision_at_k': [],
#     'auc': [],
#     'accuracy': []
# }

# for epoch in range(num_epochs):
#     model.train()
#     running_loss = 0.0
#     for inputs, labels in train_loader:
#         optimizer.zero_grad()
#         outputs = model(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()
#         running_loss += loss.item()

#     avg_loss = running_loss / len(train_loader)
#     loss_history.append(avg_loss)
    
#     # Evaluation
#     model.eval()
#     with torch.no_grad():
#         outputs = model(X_test_tensor)
#         predicted = (outputs > 0.5).float()
        
#         metrics = compute_metrics(Y_test, predicted, outputs)
#         for key in metrics_history:
#             metrics_history[key].append(metrics[key])

#     print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, "
#           f"Micro Precision: {metrics['micro_precision']:.4f}, "
#           f"Macro Precision: {metrics['macro_precision']:.4f}, "
#           f"F1 Score: {metrics['f1_score']:.4f}, "
#           f"Precision at k=4: {metrics['precision_at_k']:.4f}, "
#           f"AUC: {metrics['auc']:.4f}, "
#           f"Accuracy: {metrics['accuracy']:.4f}")

# # After training, plot loss and metrics as usual
# plot_metrics(loss_history, metrics_history)
